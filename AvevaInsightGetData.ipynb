# %%
import pickle
import os
from datetime import datetime
from AvevaInsight import AvevaInsight
from dotenv import load_dotenv
load_dotenv() 
# %matplotlib inline

# %%
auth_token = os.getenv('BEARER_TOKEN')
aveva = AvevaInsight(auth_token)

# %%
tagnames = 'CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBOI01.SteamFlow'
startTime = datetime(2023, 5, 1, 0, 0)
endTime = datetime(2023, 5, 9, 0, 0)

df = aveva.getInsightData(tagnames, startTime, endTime, RetrievalMode="Delta")
# Out:
# next: 1
# next: 2
# end: 3

# %%
df.head(10)
# Out:
#                                                  FQN              DateTime  \
# 0  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...  2023-05-01T08:00:00Z
# 1  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...  2023-05-01T08:01:00Z
# 2  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...  2023-05-01T08:02:00Z
# 3  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...  2023-05-01T08:03:00Z
# 4  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...  2023-05-01T08:04:00Z
# 5  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...  2023-05-01T08:05:00Z
# 6  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...  2023-05-01T08:06:00Z
# 7  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...  2023-05-01T08:07:00Z
# 8  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...  2023-05-01T08:08:00Z
# 9  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...  2023-05-01T08:09:00Z
#
#    OpcQuality    Value   Text  Unit
# 0         192  15020.0  15020  kg/h
# 1         192  14982.0  14982  kg/h
# 2         192  14980.0  14980  kg/h
# 3         192  15068.0  15068  kg/h
# 4         192  15050.0  15050  kg/h
# 5         192  15037.0  15037  kg/h
# 6         192  14951.0  14951  kg/h
# 7         192  14910.0  14910  kg/h
# 8         192  14991.0  14991  kg/h
# 9         192  14973.0  14973  kg/h

# %%
expression = '((TOTAL([CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBOI01.SteamFlow], 1 Month) * AVERAGE([CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBOI01.SteamEnthalpy], 1 Month) * 1000 ) / ( (TOTAL([CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBOI01.GasFuelFlow], 1 Month) * [CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBOI01.GasFuelGrossCalorificValue]) + (TOTAL([CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBOI01.LiquidFuelFlow], 1 Month) * [CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBOI01.LiquidFuelGrossCalorificValue]) + (TOTAL([CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBOI01.BiomassFuelFlow], 1 Month) * [CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBOI01.BiomassGrossCalorificValue]) ) ) AS [CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBOI01.Efficiency]'
startTime = datetime(2023, 5, 1, 0, 0)
endTime = datetime(2023, 6, 9, 0, 0)

exDF = aveva.getExpressionData(expression, startTime, endTime, RetrievalMode="Delta")
# Out:
# end: 1

# %%
exDF.head(10)
# Out:
#                                                                        FQN  \
# DateTime
# 2023-05-01 08:00:00.000  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...
# 2023-06-01 08:00:00.000  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...
# 2023-06-06 14:56:36.723  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...
# 2023-06-06 14:57:11.970  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...
# 2023-06-06 14:57:12.007  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...
# 2023-06-08 11:54:25.462  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...
# 2023-06-08 11:54:30.002  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...
# 2023-06-08 11:55:25.557  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...
# 2023-06-08 11:55:30.002  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...
# 2023-06-08 12:05:21.469  CH-Vevey.EUR.Switzerland.Vevey.UTI01.BH01.PKBO...
#
#                          OpcQuality         Value       Unit InterpolationType
# DateTime
# 2023-05-01 08:00:00.000         192  22663.175342  Undefined         StairStep
# 2023-06-01 08:00:00.000          64  23191.183520  Undefined         StairStep
# 2023-06-06 14:56:36.723          64  22441.385996  Undefined         StairStep
# 2023-06-06 14:57:11.970           0           NaN  Undefined         StairStep
# 2023-06-06 14:57:12.007          64  22441.385996  Undefined         StairStep
# 2023-06-08 11:54:25.462           0           NaN  Undefined         StairStep
# 2023-06-08 11:54:30.002          64  22441.385996  Undefined         StairStep
# 2023-06-08 11:55:25.557           0           NaN  Undefined         StairStep
# 2023-06-08 11:55:30.002          64  22441.385996  Undefined         StairStep
# 2023-06-08 12:05:21.469           0           NaN  Undefined         StairStep

# %%
tags = aveva.getTagList()

tags.head(10)
# Out:
# Failed to retrieve data. Status code: 500
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tags = aveva.getTagList()
#       3 tags.head(10)
#
# File d:\CodeRep\InsightScripts\AvevaInsight.py:129, in AvevaInsight.getTagList(self, tagnames)
#     126     tag_filter = ""
#     128 params = {"$filter": tag_filter}
# --> 129 df = self.api_call("get", api_url, params, lambda df: df)
#     131 return df
#
# File d:\CodeRep\InsightScripts\AvevaInsight.py:60, in AvevaInsight.api_call(self, method, url, params_or_payload, process_func)
#      58     else:
#      59         print(f"Failed to retrieve data. Status code: {response.status_code}")
# ---> 60         raise ValueError(f"Error from WEBAPI: {response.content}")
#      62 return df
#
# ValueError: Error from WEBAPI: b'{"title":"Internal Server error occurred","status":500,"traceId":"00-5373740ff2db0547a113ebc74ebf59a8-49dfddcb129f08f7-00"}'
